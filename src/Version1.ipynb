# %%
# !pip install clingo
# Out:
# Requirement already satisfied: clingo in c:\users\stijndp\appdata\local\anaconda3\lib\site-packages (5.8.0)
# Requirement already satisfied: cffi in c:\users\stijndp\appdata\local\anaconda3\lib\site-packages (from clingo) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\stijndp\appdata\local\anaconda3\lib\site-packages (from cffi->clingo) (2.21)

# %%
import clingo
print(clingo.__version__)
# Out:
# 5.8.0

# %%
import time
import clingo

def solve_asp(program: str = None, files=None, models: int = 0):
    """
    Console-style Clingo output from within a Jupyter notebook.

    Parameters:
    - program:   A string containing an ASP (Answer Set Programming) program (optional).
    - files:     A list of paths to .lp files containing ASP code (optional).
    - models:    Number of models to display (0 = all), similar to the Clingo CLI behavior.

    Example usage:
        solve_asp(program=\"\"\" a. b :- a. #show a/0. \"\"\")
        solve_asp(files=[\"myFirstLp.lp\"], models=0)
    """

    start = time.perf_counter()

    ctl = clingo.Control(arguments=[str(models)] if models is not None else [])
    # (same semantics as CLI: '0' means all models)

    # Add program sources
    if program is not None:
        ctl.add("base", [], program)
    if files:
        for p in files:
            with open(p, "r", encoding="utf-8") as f:
                ctl.add("base", [], f.read())

    # Ground the program
    ctl.ground([("base", [])])

    # Collect and print output models like the CLI
    model_count = 0
    with ctl.solve(yield_=True) as handle:
        for model in handle:
            model_count += 1
            # If there are #show directives, use those; otherwise show all atoms
            shown = model.symbols(shown=True)
            if not shown:
                shown = model.symbols(atoms=True)

            # Sort alphabetically by string representation for stable, neat output
            line = " ".join(sorted(map(str, shown)))
            print(f"Answer: {model_count}")
            if line:
                print(line)

    # Print final result and statistics in Clingo-style format
    status = "SATISFIABLE" if model_count > 0 else "UNSATISFIABLE"
    elapsed = time.perf_counter() - start
    # Minimal statistics, similar to the CLI
    print(status)
    print(f"Models      : {model_count}")
    print(f"Calls       : 1")
    print(f"Time        : {elapsed:.3f}s (Solving: {elapsed:.2f}s 1st Model: {'n/a' if model_count==0 else '0.00s'} Unsat: {'n/a' if model_count>0 else f'{elapsed:.2f}s'})")

# %%
program = r"""
person(alice; bob).
rain.
happy(X) :- person(X), not sad(X).
sad(alice) :- rain.
:- happy(X), sad(X).
#show happy/1.
#show sad/1.
"""
solve_asp(program=program, models=0)
# Out:
# Answer: 1
# happy(bob) sad(alice)
# SATISFIABLE
# Models      : 1
# Calls       : 1
# Time        : 0.001s (Solving: 0.00s 1st Model: 0.00s Unsat: n/a)

# %%
program = r"""

#const n=5.

row(1..n).
col(1..n).
square(X,Y) :- row(X), col(Y).

move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 1 = |X1-X2|, 2 = |Y1-Y2|.
move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 2 = |X1-X2|, 1 = |Y1-Y2|.

% Guess exactly one successor and one predecessor per square
1 { succ(X,Y,X2,Y2) : move(X,Y,X2,Y2) } 1 :- square(X,Y).
1 { pred(X,Y,X2,Y2) : move(X2,Y2,X,Y) } 1 :- square(X,Y).

% Link pred/succ for consistency
:- succ(X,Y,X2,Y2), not pred(X2,Y2,X,Y).
:- pred(X,Y,X2,Y2), not succ(X2,Y2,X,Y).

% Ensure single cycle covering all squares (reachability from a fixed anchor)
anchor(1,1).  % pick an arbitrary anchor
reach(X2,Y2) :- anchor(X1,Y1), succ(X1,Y1,X2,Y2).
reach(X3,Y3) :- reach(X2,Y2), succ(X2,Y2,X3,Y3).
:- square(X,Y), not reach(X,Y).

#show succ/4.

"""
solve_asp(program=program, models=0)
# Out:
# UNSATISFIABLE
# Models      : 0
# Calls       : 1
# Time        : 0.004s (Solving: 0.00s 1st Model: n/a Unsat: 0.00s)

# %%
program = r"""

square(1..3, 1..3).

startsquare(1,1).

step(1..8).

move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 1 = |X1-X2|, 2 = |Y1-Y2|.
move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 2 = |X1-X2|, 1 = |Y1-Y2|.


route(X,Y,1) :- startsquare(X,Y), step(1).
route(X,Y,8) :- square(X,Y), step(8).

route(X2,Y2,Z2) :- route(X1,Y1,Z1), move(X1,Y1,X2,Y2), step(Z1), step(Z2), Z2 = Z1 + 1.





#show route/3.

"""
solve_asp(program=program, models=0)
# Out:
# Answer: 1
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(1,1,8) route(1,2,4) route(1,2,6) route(1,2,8) route(1,3,3) route(1,3,5) route(1,3,7) route(1,3,8) route(2,1,4) route(2,1,6) route(2,1,8) route(2,2,8) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,3) route(3,1,5) route(3,1,7) route(3,1,8) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8) route(3,3,5) route(3,3,7) route(3,3,8)
# SATISFIABLE
# Models      : 1
# Calls       : 1
# Time        : 0.001s (Solving: 0.00s 1st Model: 0.00s Unsat: n/a)

# %%
program = r"""

% Board
square(1..5, 1..5).

% Knight moves
move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 1 = |X1-X2|, 2 = |Y1-Y2|.
move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 2 = |X1-X2|, 1 = |Y1-Y2|.

% Steps
step(1..5*5).

% Start
route(1,1,1).

% Exactly one square at each step
{ route(X2,Y2,Z2) : route(X1,Y1,Z1), move(X1,Y1,X2,Y2), Z2 = Z1 + 1 } = 1 :- step(Z2), Z2 > 1.

:- route(X,Y,Z1), route(X,Y,Z2), Z1 != Z2.


#show route/3.

"""
solve_asp(program=program, models=0)
# Out:
# Answer: 1
# route(1,1,1) route(1,2,10) route(1,3,25) route(1,4,20) route(1,5,3) route(2,1,24) route(2,2,19) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,6) route(4,4,13) route(4,5,16) route(5,1,7) route(5,2,12) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 2
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,20) route(1,5,25) route(2,1,16) route(2,2,19) route(2,3,24) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,4) route(4,4,13) route(4,5,8) route(5,1,3) route(5,2,12) route(5,3,7) route(5,4,22) route(5,5,5)
# Answer: 3
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,20) route(1,5,23) route(2,1,16) route(2,2,5) route(2,3,22) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,2) route(3,3,19) route(3,4,24) route(3,5,21) route(4,1,6) route(4,2,17) route(4,3,4) route(4,4,13) route(4,5,8) route(5,1,3) route(5,2,12) route(5,3,7) route(5,4,18) route(5,5,25)
# Answer: 4
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,22) route(1,5,3) route(2,1,18) route(2,2,23) route(2,3,2) route(2,4,9) route(2,5,16) route(3,1,13) route(3,2,8) route(3,3,11) route(3,4,4) route(3,5,21) route(4,1,24) route(4,2,19) route(4,3,6) route(4,4,15) route(4,5,10) route(5,1,7) route(5,2,14) route(5,3,25) route(5,4,20) route(5,5,5)
# Answer: 5
# route(1,1,1) route(1,2,8) route(1,3,3) route(1,4,14) route(1,5,21) route(2,1,16) route(2,2,13) route(2,3,20) route(2,4,9) route(2,5,4) route(3,1,7) route(3,2,2) route(3,3,15) route(3,4,22) route(3,5,19) route(4,1,12) route(4,2,17) route(4,3,24) route(4,4,5) route(4,5,10) route(5,1,25) route(5,2,6) route(5,3,11) route(5,4,18) route(5,5,23)
# Answer: 6
# route(1,1,1) route(1,2,10) route(1,3,19) route(1,4,4) route(1,5,25) route(2,1,18) route(2,2,5) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,20) route(3,3,15) route(3,4,24) route(3,5,3) route(4,1,6) route(4,2,17) route(4,3,22) route(4,4,13) route(4,5,8) route(5,1,21) route(5,2,12) route(5,3,7) route(5,4,16) route(5,5,23)
# Answer: 7
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,14) route(1,5,3) route(2,1,22) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,20) route(3,1,17) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,25) route(4,1,12) route(4,2,23) route(4,3,6) route(4,4,19) route(4,5,10) route(5,1,7) route(5,2,18) route(5,3,11) route(5,4,24) route(5,5,5)
# Answer: 8
# route(1,1,1) route(1,2,10) route(1,3,21) route(1,4,16) route(1,5,3) route(2,1,20) route(2,2,5) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,22) route(3,3,15) route(3,4,4) route(3,5,17) route(4,1,6) route(4,2,19) route(4,3,24) route(4,4,13) route(4,5,8) route(5,1,23) route(5,2,12) route(5,3,7) route(5,4,18) route(5,5,25)
# Answer: 9
# route(1,1,1) route(1,2,10) route(1,3,19) route(1,4,14) route(1,5,25) route(2,1,18) route(2,2,13) route(2,3,24) route(2,4,9) route(2,5,20) route(3,1,23) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,4) route(4,4,21) route(4,5,8) route(5,1,3) route(5,2,22) route(5,3,7) route(5,4,16) route(5,5,5)
# Answer: 10
# route(1,1,1) route(1,2,8) route(1,3,19) route(1,4,14) route(1,5,23) route(2,1,18) route(2,2,13) route(2,3,22) route(2,4,9) route(2,5,20) route(3,1,5) route(3,2,2) route(3,3,7) route(3,4,24) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,4) route(4,4,21) route(4,5,10) route(5,1,3) route(5,2,6) route(5,3,11) route(5,4,16) route(5,5,25)
# Answer: 11
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,22) route(1,5,25) route(2,1,16) route(2,2,21) route(2,3,24) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,23) route(4,1,20) route(4,2,17) route(4,3,4) route(4,4,13) route(4,5,8) route(5,1,3) route(5,2,12) route(5,3,7) route(5,4,18) route(5,5,5)
# Answer: 12
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,18) route(1,5,23) route(2,1,16) route(2,2,5) route(2,3,22) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,2) route(3,3,17) route(3,4,24) route(3,5,19) route(4,1,6) route(4,2,21) route(4,3,4) route(4,4,13) route(4,5,8) route(5,1,3) route(5,2,12) route(5,3,7) route(5,4,20) route(5,5,25)
# Answer: 13
# route(1,1,1) route(1,2,10) route(1,3,19) route(1,4,14) route(1,5,23) route(2,1,18) route(2,2,5) route(2,3,22) route(2,4,9) route(2,5,20) route(3,1,11) route(3,2,2) route(3,3,13) route(3,4,24) route(3,5,15) route(4,1,6) route(4,2,17) route(4,3,4) route(4,4,21) route(4,5,8) route(5,1,3) route(5,2,12) route(5,3,7) route(5,4,16) route(5,5,25)
# Answer: 14
# route(1,1,1) route(1,2,10) route(1,3,21) route(1,4,16) route(1,5,25) route(2,1,20) route(2,2,15) route(2,3,24) route(2,4,9) route(2,5,22) route(3,1,11) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,17) route(4,1,14) route(4,2,19) route(4,3,4) route(4,4,23) route(4,5,8) route(5,1,3) route(5,2,12) route(5,3,7) route(5,4,18) route(5,5,5)
# Answer: 15
# route(1,1,1) route(1,2,10) route(1,3,17) route(1,4,12) route(1,5,23) route(2,1,16) route(2,2,5) route(2,3,22) route(2,4,9) route(2,5,18) route(3,1,21) route(3,2,2) route(3,3,11) route(3,4,24) route(3,5,13) route(4,1,6) route(4,2,15) route(4,3,4) route(4,4,19) route(4,5,8) route(5,1,3) route(5,2,20) route(5,3,7) route(5,4,14) route(5,5,25)
# Answer: 16
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,22) route(1,5,3) route(2,1,16) route(2,2,21) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,23) route(4,1,20) route(4,2,25) route(4,3,6) route(4,4,13) route(4,5,18) route(5,1,7) route(5,2,12) route(5,3,19) route(5,4,24) route(5,5,5)
# Answer: 17
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,6) route(1,5,21) route(2,1,16) route(2,2,5) route(2,3,20) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,2) route(3,3,7) route(3,4,22) route(3,5,19) route(4,1,4) route(4,2,17) route(4,3,24) route(4,4,13) route(4,5,8) route(5,1,25) route(5,2,12) route(5,3,3) route(5,4,18) route(5,5,23)
# Answer: 18
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,24) route(1,5,3) route(2,1,16) route(2,2,23) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,8) route(3,3,19) route(3,4,4) route(3,5,25) route(4,1,22) route(4,2,17) route(4,3,6) route(4,4,13) route(4,5,20) route(5,1,7) route(5,2,12) route(5,3,21) route(5,4,18) route(5,5,5)
# Answer: 19
# route(1,1,1) route(1,2,8) route(1,3,15) route(1,4,20) route(1,5,3) route(2,1,16) route(2,2,21) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,7) route(3,2,24) route(3,3,11) route(3,4,4) route(3,5,19) route(4,1,22) route(4,2,17) route(4,3,6) route(4,4,13) route(4,5,10) route(5,1,25) route(5,2,12) route(5,3,23) route(5,4,18) route(5,5,5)
# Answer: 20
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,20) route(1,5,3) route(2,1,16) route(2,2,25) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,8) route(3,3,21) route(3,4,4) route(3,5,19) route(4,1,24) route(4,2,17) route(4,3,6) route(4,4,13) route(4,5,22) route(5,1,7) route(5,2,12) route(5,3,23) route(5,4,18) route(5,5,5)
# Answer: 21
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,20) route(1,5,3) route(2,1,16) route(2,2,21) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,19) route(4,1,22) route(4,2,17) route(4,3,6) route(4,4,13) route(4,5,24) route(5,1,7) route(5,2,12) route(5,3,25) route(5,4,18) route(5,5,5)
# Answer: 22
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,20) route(1,5,3) route(2,1,16) route(2,2,21) route(2,3,2) route(2,4,9) route(2,5,14) route(3,1,11) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,19) route(4,1,22) route(4,2,17) route(4,3,6) route(4,4,13) route(4,5,24) route(5,1,7) route(5,2,12) route(5,3,23) route(5,4,18) route(5,5,5)
# Answer: 23
# route(1,1,1) route(1,2,18) route(1,3,23) route(1,4,14) route(1,5,3) route(2,1,24) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,22) route(3,1,19) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,25) route(4,3,6) route(4,4,21) route(4,5,10) route(5,1,7) route(5,2,20) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 24
# route(1,1,1) route(1,2,8) route(1,3,3) route(1,4,14) route(1,5,21) route(2,1,18) route(2,2,13) route(2,3,20) route(2,4,9) route(2,5,4) route(3,1,7) route(3,2,2) route(3,3,17) route(3,4,22) route(3,5,15) route(4,1,12) route(4,2,19) route(4,3,24) route(4,4,5) route(4,5,10) route(5,1,25) route(5,2,6) route(5,3,11) route(5,4,16) route(5,5,23)
# Answer: 25
# route(1,1,1) route(1,2,10) route(1,3,19) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,5) route(2,3,2) route(2,4,9) route(2,5,20) route(3,1,11) route(3,2,22) route(3,3,13) route(3,4,4) route(3,5,15) route(4,1,6) route(4,2,17) route(4,3,24) route(4,4,21) route(4,5,8) route(5,1,23) route(5,2,12) route(5,3,7) route(5,4,16) route(5,5,25)
# Answer: 26
# route(1,1,1) route(1,2,10) route(1,3,17) route(1,4,4) route(1,5,25) route(2,1,16) route(2,2,5) route(2,3,2) route(2,4,9) route(2,5,18) route(3,1,11) route(3,2,20) route(3,3,13) route(3,4,24) route(3,5,3) route(4,1,6) route(4,2,15) route(4,3,22) route(4,4,19) route(4,5,8) route(5,1,21) route(5,2,12) route(5,3,7) route(5,4,14) route(5,5,23)
# Answer: 27
# route(1,1,1) route(1,2,14) route(1,3,19) route(1,4,24) route(1,5,3) route(2,1,20) route(2,2,25) route(2,3,2) route(2,4,9) route(2,5,18) route(3,1,15) route(3,2,8) route(3,3,13) route(3,4,4) route(3,5,23) route(4,1,12) route(4,2,21) route(4,3,6) route(4,4,17) route(4,5,10) route(5,1,7) route(5,2,16) route(5,3,11) route(5,4,22) route(5,5,5)
# Answer: 28
# route(1,1,1) route(1,2,10) route(1,3,23) route(1,4,18) route(1,5,3) route(2,1,22) route(2,2,17) route(2,3,2) route(2,4,9) route(2,5,24) route(3,1,11) route(3,2,8) route(3,3,13) route(3,4,4) route(3,5,19) route(4,1,16) route(4,2,21) route(4,3,6) route(4,4,25) route(4,5,14) route(5,1,7) route(5,2,12) route(5,3,15) route(5,4,20) route(5,5,5)
# Answer: 29
# route(1,1,1) route(1,2,8) route(1,3,19) route(1,4,14) route(1,5,25) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,4) route(3,1,7) route(3,2,20) route(3,3,5) route(3,4,24) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,22) route(4,4,3) route(4,5,10) route(5,1,21) route(5,2,6) route(5,3,11) route(5,4,16) route(5,5,23)
# Answer: 30
# route(1,1,1) route(1,2,8) route(1,3,19) route(1,4,14) route(1,5,25) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,6) route(3,1,3) route(3,2,20) route(3,3,7) route(3,4,24) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,22) route(4,4,5) route(4,5,10) route(5,1,21) route(5,2,4) route(5,3,11) route(5,4,16) route(5,5,23)
# Answer: 31
# route(1,1,1) route(1,2,24) route(1,3,19) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,20) route(3,1,25) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,6) route(4,4,21) route(4,5,10) route(5,1,7) route(5,2,22) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 32
# route(1,1,1) route(1,2,24) route(1,3,19) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,20) route(3,1,23) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,6) route(4,4,21) route(4,5,10) route(5,1,7) route(5,2,22) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 33
# route(1,1,1) route(1,2,8) route(1,3,19) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,20) route(3,1,7) route(3,2,24) route(3,3,21) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,6) route(4,4,23) route(4,5,10) route(5,1,25) route(5,2,22) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 34
# route(1,1,1) route(1,2,22) route(1,3,19) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,20) route(3,1,23) route(3,2,8) route(3,3,21) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,6) route(4,4,25) route(4,5,10) route(5,1,7) route(5,2,24) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 35
# route(1,1,1) route(1,2,20) route(1,3,25) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,24) route(3,1,21) route(3,2,8) route(3,3,19) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,6) route(4,4,23) route(4,5,10) route(5,1,7) route(5,2,22) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 36
# route(1,1,1) route(1,2,8) route(1,3,23) route(1,4,14) route(1,5,3) route(2,1,18) route(2,2,13) route(2,3,2) route(2,4,9) route(2,5,22) route(3,1,7) route(3,2,24) route(3,3,19) route(3,4,4) route(3,5,15) route(4,1,12) route(4,2,17) route(4,3,6) route(4,4,21) route(4,5,10) route(5,1,25) route(5,2,20) route(5,3,11) route(5,4,16) route(5,5,5)
# Answer: 37
# route(1,1,1) route(1,2,10) route(1,3,21) route(1,4,16) route(1,5,3) route(2,1,20) route(2,2,15) route(2,3,2) route(2,4,9) route(2,5,22) route(3,1,25) route(3,2,8) route(3,3,11) route(3,4,4) route(3,5,17) route(4,1,14) route(4,2,19) route(4,3,6) route(4,4,23) route(4,5,12) route(5,1,7) route(5,2,24) route(5,3,13) route(5,4,18) route(5,5,5)
# Answer: 38
# route(1,1,1) route(1,2,18) route(1,3,11) route(1,4,6) route(1,5,21) route(2,1,10) route(2,2,5) route(2,3,20) route(2,4,17) route(2,5,12) route(3,1,19) route(3,2,2) route(3,3,15) route(3,4,22) route(3,5,7) route(4,1,4) route(4,2,9) route(4,3,24) route(4,4,13) route(4,5,16) route(5,1,25) route(5,2,14) route(5,3,3) route(5,4,8) route(5,5,23)
# Answer: 39
# route(1,1,1) route(1,2,18) route(1,3,11) route(1,4,6) route(1,5,23) route(2,1,10) route(2,2,5) route(2,3,22) route(2,4,17) route(2,5,12) route(3,1,19) route(3,2,2) route(3,3,13) route(3,4,24) route(3,5,7) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,21) route(4,5,16) route(5,1,3) route(5,2,20) route(5,3,15) route(5,4,8) route(5,5,25)
# Answer: 40
# route(1,1,1) route(1,2,18) route(1,3,11) route(1,4,6) route(1,5,3) route(2,1,10) route(2,2,5) route(2,3,2) route(2,4,17) route(2,5,12) route(3,1,19) route(3,2,22) route(3,3,13) route(3,4,4) route(3,5,7) route(4,1,14) route(4,2,9) route(4,3,24) route(4,4,21) route(4,5,16) route(5,1,23) route(5,2,20) route(5,3,15) route(5,4,8) route(5,5,25)
# Answer: 41
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,6) route(1,5,3) route(2,1,10) route(2,2,5) route(2,3,2) route(2,4,17) route(2,5,12) route(3,1,15) route(3,2,22) route(3,3,19) route(3,4,4) route(3,5,7) route(4,1,20) route(4,2,9) route(4,3,24) route(4,4,13) route(4,5,18) route(5,1,23) route(5,2,14) route(5,3,21) route(5,4,8) route(5,5,25)
# Answer: 42
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,4) route(1,5,25) route(2,1,10) route(2,2,5) route(2,3,2) route(2,4,17) route(2,5,12) route(3,1,15) route(3,2,20) route(3,3,7) route(3,4,24) route(3,5,3) route(4,1,6) route(4,2,9) route(4,3,22) route(4,4,13) route(4,5,18) route(5,1,21) route(5,2,14) route(5,3,19) route(5,4,8) route(5,5,23)
# Answer: 43
# route(1,1,1) route(1,2,14) route(1,3,19) route(1,4,6) route(1,5,23) route(2,1,20) route(2,2,5) route(2,3,22) route(2,4,13) route(2,5,18) route(3,1,15) route(3,2,2) route(3,3,9) route(3,4,24) route(3,5,7) route(4,1,10) route(4,2,21) route(4,3,4) route(4,4,17) route(4,5,12) route(5,1,3) route(5,2,16) route(5,3,11) route(5,4,8) route(5,5,25)
# Answer: 44
# route(1,1,1) route(1,2,20) route(1,3,15) route(1,4,10) route(1,5,3) route(2,1,14) route(2,2,5) route(2,3,2) route(2,4,21) route(2,5,16) route(3,1,19) route(3,2,22) route(3,3,9) route(3,4,4) route(3,5,11) route(4,1,6) route(4,2,13) route(4,3,24) route(4,4,17) route(4,5,8) route(5,1,23) route(5,2,18) route(5,3,7) route(5,4,12) route(5,5,25)
# Answer: 45
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,4) route(1,5,25) route(2,1,12) route(2,2,5) route(2,3,2) route(2,4,19) route(2,5,14) route(3,1,17) route(3,2,20) route(3,3,9) route(3,4,24) route(3,5,3) route(4,1,6) route(4,2,11) route(4,3,22) route(4,4,15) route(4,5,8) route(5,1,21) route(5,2,16) route(5,3,7) route(5,4,10) route(5,5,23)
# Answer: 46
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,6) route(1,5,21) route(2,1,18) route(2,2,5) route(2,3,20) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,2) route(3,3,9) route(3,4,22) route(3,5,7) route(4,1,4) route(4,2,19) route(4,3,24) route(4,4,15) route(4,5,10) route(5,1,25) route(5,2,14) route(5,3,3) route(5,4,8) route(5,5,23)
# Answer: 47
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,6) route(1,5,21) route(2,1,10) route(2,2,5) route(2,3,20) route(2,4,15) route(2,5,12) route(3,1,17) route(3,2,2) route(3,3,13) route(3,4,22) route(3,5,7) route(4,1,4) route(4,2,9) route(4,3,24) route(4,4,19) route(4,5,14) route(5,1,25) route(5,2,18) route(5,3,3) route(5,4,8) route(5,5,23)
# Answer: 48
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,6) route(1,5,3) route(2,1,10) route(2,2,5) route(2,3,2) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,22) route(3,3,11) route(3,4,4) route(3,5,7) route(4,1,12) route(4,2,9) route(4,3,24) route(4,4,19) route(4,5,14) route(5,1,23) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,25)
# Answer: 49
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,6) route(1,5,3) route(2,1,10) route(2,2,5) route(2,3,2) route(2,4,21) route(2,5,12) route(3,1,15) route(3,2,22) route(3,3,17) route(3,4,4) route(3,5,7) route(4,1,18) route(4,2,9) route(4,3,24) route(4,4,13) route(4,5,20) route(5,1,23) route(5,2,14) route(5,3,19) route(5,4,8) route(5,5,25)
# Answer: 50
# route(1,1,1) route(1,2,20) route(1,3,11) route(1,4,6) route(1,5,23) route(2,1,10) route(2,2,5) route(2,3,22) route(2,4,19) route(2,5,12) route(3,1,21) route(3,2,2) route(3,3,15) route(3,4,24) route(3,5,7) route(4,1,16) route(4,2,9) route(4,3,4) route(4,4,13) route(4,5,18) route(5,1,3) route(5,2,14) route(5,3,17) route(5,4,8) route(5,5,25)
# Answer: 51
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,6) route(1,5,23) route(2,1,18) route(2,2,5) route(2,3,22) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,2) route(3,3,7) route(3,4,24) route(3,5,21) route(4,1,8) route(4,2,19) route(4,3,4) route(4,4,15) route(4,5,10) route(5,1,3) route(5,2,14) route(5,3,9) route(5,4,20) route(5,5,25)
# Answer: 52
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,8) route(1,5,3) route(2,1,12) route(2,2,5) route(2,3,2) route(2,4,19) route(2,5,14) route(3,1,17) route(3,2,22) route(3,3,7) route(3,4,4) route(3,5,9) route(4,1,6) route(4,2,11) route(4,3,24) route(4,4,15) route(4,5,20) route(5,1,23) route(5,2,16) route(5,3,21) route(5,4,10) route(5,5,25)
# Answer: 53
# route(1,1,1) route(1,2,6) route(1,3,17) route(1,4,12) route(1,5,21) route(2,1,16) route(2,2,11) route(2,3,20) route(2,4,5) route(2,5,18) route(3,1,7) route(3,2,2) route(3,3,9) route(3,4,22) route(3,5,13) route(4,1,10) route(4,2,15) route(4,3,24) route(4,4,19) route(4,5,4) route(5,1,25) route(5,2,8) route(5,3,3) route(5,4,14) route(5,5,23)
# Answer: 54
# route(1,1,1) route(1,2,6) route(1,3,17) route(1,4,12) route(1,5,21) route(2,1,18) route(2,2,11) route(2,3,20) route(2,4,7) route(2,5,16) route(3,1,5) route(3,2,2) route(3,3,15) route(3,4,22) route(3,5,13) route(4,1,10) route(4,2,19) route(4,3,24) route(4,4,3) route(4,5,8) route(5,1,25) route(5,2,4) route(5,3,9) route(5,4,14) route(5,5,23)
# Answer: 55
# route(1,1,1) route(1,2,4) route(1,3,17) route(1,4,12) route(1,5,21) route(2,1,16) route(2,2,11) route(2,3,20) route(2,4,3) route(2,5,18) route(3,1,5) route(3,2,2) route(3,3,7) route(3,4,22) route(3,5,13) route(4,1,10) route(4,2,15) route(4,3,24) route(4,4,19) route(4,5,8) route(5,1,25) route(5,2,6) route(5,3,9) route(5,4,14) route(5,5,23)
# Answer: 56
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,8) route(1,5,21) route(2,1,18) route(2,2,7) route(2,3,20) route(2,4,3) route(2,5,16) route(3,1,13) route(3,2,2) route(3,3,11) route(3,4,22) route(3,5,9) route(4,1,6) route(4,2,19) route(4,3,24) route(4,4,15) route(4,5,4) route(5,1,25) route(5,2,14) route(5,3,5) route(5,4,10) route(5,5,23)
# Answer: 57
# route(1,1,1) route(1,2,4) route(1,3,9) route(1,4,16) route(1,5,21) route(2,1,10) route(2,2,15) route(2,3,20) route(2,4,3) route(2,5,8) route(3,1,5) route(3,2,2) route(3,3,11) route(3,4,22) route(3,5,17) route(4,1,14) route(4,2,19) route(4,3,24) route(4,4,7) route(4,5,12) route(5,1,25) route(5,2,6) route(5,3,13) route(5,4,18) route(5,5,23)
# Answer: 58
# route(1,1,1) route(1,2,16) route(1,3,3) route(1,4,10) route(1,5,21) route(2,1,6) route(2,2,11) route(2,3,20) route(2,4,15) route(2,5,4) route(3,1,17) route(3,2,2) route(3,3,5) route(3,4,22) route(3,5,9) route(4,1,12) route(4,2,7) route(4,3,24) route(4,4,19) route(4,5,14) route(5,1,25) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,23)
# Answer: 59
# route(1,1,1) route(1,2,10) route(1,3,3) route(1,4,16) route(1,5,21) route(2,1,4) route(2,2,15) route(2,3,20) route(2,4,11) route(2,5,6) route(3,1,9) route(3,2,2) route(3,3,5) route(3,4,22) route(3,5,17) route(4,1,14) route(4,2,19) route(4,3,24) route(4,4,7) route(4,5,12) route(5,1,25) route(5,2,8) route(5,3,13) route(5,4,18) route(5,5,23)
# Answer: 60
# route(1,1,1) route(1,2,4) route(1,3,15) route(1,4,10) route(1,5,21) route(2,1,14) route(2,2,9) route(2,3,20) route(2,4,3) route(2,5,16) route(3,1,19) route(3,2,2) route(3,3,5) route(3,4,22) route(3,5,11) route(4,1,8) route(4,2,13) route(4,3,24) route(4,4,17) route(4,5,6) route(5,1,25) route(5,2,18) route(5,3,7) route(5,4,12) route(5,5,23)
# Answer: 61
# route(1,1,1) route(1,2,18) route(1,3,7) route(1,4,12) route(1,5,21) route(2,1,8) route(2,2,13) route(2,3,20) route(2,4,17) route(2,5,6) route(3,1,19) route(3,2,2) route(3,3,5) route(3,4,22) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,24) route(4,4,3) route(4,5,16) route(5,1,25) route(5,2,4) route(5,3,15) route(5,4,10) route(5,5,23)
# Answer: 62
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,8) route(1,5,21) route(2,1,12) route(2,2,7) route(2,3,20) route(2,4,3) route(2,5,14) route(3,1,19) route(3,2,2) route(3,3,17) route(3,4,22) route(3,5,9) route(4,1,6) route(4,2,11) route(4,3,24) route(4,4,15) route(4,5,4) route(5,1,25) route(5,2,16) route(5,3,5) route(5,4,10) route(5,5,23)
# Answer: 63
# route(1,1,1) route(1,2,16) route(1,3,13) route(1,4,8) route(1,5,21) route(2,1,12) route(2,2,7) route(2,3,20) route(2,4,3) route(2,5,14) route(3,1,17) route(3,2,2) route(3,3,15) route(3,4,22) route(3,5,9) route(4,1,6) route(4,2,11) route(4,3,24) route(4,4,19) route(4,5,4) route(5,1,25) route(5,2,18) route(5,3,5) route(5,4,10) route(5,5,23)
# Answer: 64
# route(1,1,1) route(1,2,14) route(1,3,3) route(1,4,8) route(1,5,21) route(2,1,4) route(2,2,9) route(2,3,20) route(2,4,13) route(2,5,18) route(3,1,15) route(3,2,2) route(3,3,17) route(3,4,22) route(3,5,7) route(4,1,10) route(4,2,5) route(4,3,24) route(4,4,19) route(4,5,12) route(5,1,25) route(5,2,16) route(5,3,11) route(5,4,6) route(5,5,23)
# Answer: 65
# route(1,1,1) route(1,2,16) route(1,3,5) route(1,4,10) route(1,5,21) route(2,1,6) route(2,2,11) route(2,3,20) route(2,4,15) route(2,5,4) route(3,1,19) route(3,2,2) route(3,3,17) route(3,4,22) route(3,5,9) route(4,1,12) route(4,2,7) route(4,3,24) route(4,4,3) route(4,5,14) route(5,1,25) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,23)
# Answer: 66
# route(1,1,1) route(1,2,6) route(1,3,11) route(1,4,18) route(1,5,21) route(2,1,12) route(2,2,17) route(2,3,20) route(2,4,5) route(2,5,10) route(3,1,7) route(3,2,2) route(3,3,15) route(3,4,22) route(3,5,19) route(4,1,16) route(4,2,13) route(4,3,24) route(4,4,9) route(4,5,4) route(5,1,25) route(5,2,8) route(5,3,3) route(5,4,14) route(5,5,23)
# Answer: 67
# route(1,1,1) route(1,2,14) route(1,3,3) route(1,4,8) route(1,5,21) route(2,1,4) route(2,2,9) route(2,3,20) route(2,4,13) route(2,5,16) route(3,1,19) route(3,2,2) route(3,3,15) route(3,4,22) route(3,5,7) route(4,1,10) route(4,2,5) route(4,3,24) route(4,4,17) route(4,5,12) route(5,1,25) route(5,2,18) route(5,3,11) route(5,4,6) route(5,5,23)
# Answer: 68
# route(1,1,1) route(1,2,6) route(1,3,15) route(1,4,12) route(1,5,21) route(2,1,16) route(2,2,11) route(2,3,20) route(2,4,7) route(2,5,14) route(3,1,5) route(3,2,2) route(3,3,13) route(3,4,22) route(3,5,19) route(4,1,10) route(4,2,17) route(4,3,24) route(4,4,3) route(4,5,8) route(5,1,25) route(5,2,4) route(5,3,9) route(5,4,18) route(5,5,23)
# Answer: 69
# route(1,1,1) route(1,2,4) route(1,3,9) route(1,4,18) route(1,5,21) route(2,1,10) route(2,2,17) route(2,3,20) route(2,4,3) route(2,5,8) route(3,1,5) route(3,2,2) route(3,3,13) route(3,4,22) route(3,5,19) route(4,1,16) route(4,2,11) route(4,3,24) route(4,4,7) route(4,5,14) route(5,1,25) route(5,2,6) route(5,3,15) route(5,4,12) route(5,5,23)
# Answer: 70
# route(1,1,1) route(1,2,6) route(1,3,11) route(1,4,16) route(1,5,21) route(2,1,12) route(2,2,15) route(2,3,20) route(2,4,5) route(2,5,10) route(3,1,7) route(3,2,2) route(3,3,13) route(3,4,22) route(3,5,17) route(4,1,14) route(4,2,19) route(4,3,24) route(4,4,9) route(4,5,4) route(5,1,25) route(5,2,8) route(5,3,3) route(5,4,18) route(5,5,23)
# Answer: 71
# route(1,1,1) route(1,2,10) route(1,3,5) route(1,4,16) route(1,5,21) route(2,1,6) route(2,2,15) route(2,3,20) route(2,4,11) route(2,5,4) route(3,1,9) route(3,2,2) route(3,3,7) route(3,4,22) route(3,5,17) route(4,1,14) route(4,2,19) route(4,3,24) route(4,4,3) route(4,5,12) route(5,1,25) route(5,2,8) route(5,3,13) route(5,4,18) route(5,5,23)
# Answer: 72
# route(1,1,1) route(1,2,12) route(1,3,3) route(1,4,18) route(1,5,21) route(2,1,4) route(2,2,17) route(2,3,20) route(2,4,13) route(2,5,8) route(3,1,11) route(3,2,2) route(3,3,7) route(3,4,22) route(3,5,19) route(4,1,16) route(4,2,5) route(4,3,24) route(4,4,9) route(4,5,14) route(5,1,25) route(5,2,10) route(5,3,15) route(5,4,6) route(5,5,23)
# Answer: 73
# route(1,1,1) route(1,2,18) route(1,3,3) route(1,4,12) route(1,5,21) route(2,1,8) route(2,2,13) route(2,3,20) route(2,4,17) route(2,5,4) route(3,1,19) route(3,2,2) route(3,3,7) route(3,4,22) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,24) route(4,4,5) route(4,5,16) route(5,1,25) route(5,2,6) route(5,3,15) route(5,4,10) route(5,5,23)
# Answer: 74
# route(1,1,1) route(1,2,6) route(1,3,15) route(1,4,10) route(1,5,21) route(2,1,14) route(2,2,9) route(2,3,20) route(2,4,5) route(2,5,16) route(3,1,19) route(3,2,2) route(3,3,7) route(3,4,22) route(3,5,11) route(4,1,8) route(4,2,13) route(4,3,24) route(4,4,17) route(4,5,4) route(5,1,25) route(5,2,18) route(5,3,3) route(5,4,12) route(5,5,23)
# Answer: 75
# route(1,1,1) route(1,2,12) route(1,3,5) route(1,4,18) route(1,5,21) route(2,1,6) route(2,2,17) route(2,3,20) route(2,4,13) route(2,5,4) route(3,1,11) route(3,2,2) route(3,3,9) route(3,4,22) route(3,5,19) route(4,1,16) route(4,2,7) route(4,3,24) route(4,4,3) route(4,5,14) route(5,1,25) route(5,2,10) route(5,3,15) route(5,4,8) route(5,5,23)
# Answer: 76
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,8) route(1,5,21) route(2,1,16) route(2,2,7) route(2,3,20) route(2,4,3) route(2,5,14) route(3,1,11) route(3,2,2) route(3,3,9) route(3,4,22) route(3,5,19) route(4,1,6) route(4,2,17) route(4,3,24) route(4,4,13) route(4,5,4) route(5,1,25) route(5,2,12) route(5,3,5) route(5,4,18) route(5,5,23)
# Answer: 77
# route(1,1,1) route(1,2,14) route(1,3,25) route(1,4,20) route(1,5,7) route(2,1,24) route(2,2,19) route(2,3,8) route(2,4,15) route(2,5,12) route(3,1,9) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,4) route(4,4,11) route(4,5,16) route(5,1,3) route(5,2,10) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 78
# route(1,1,1) route(1,2,10) route(1,3,17) route(1,4,22) route(1,5,7) route(2,1,18) route(2,2,23) route(2,3,8) route(2,4,11) route(2,5,16) route(3,1,9) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,21) route(4,1,24) route(4,2,19) route(4,3,4) route(4,4,15) route(4,5,12) route(5,1,3) route(5,2,14) route(5,3,25) route(5,4,20) route(5,5,5)
# Answer: 79
# route(1,1,1) route(1,2,14) route(1,3,25) route(1,4,20) route(1,5,7) route(2,1,24) route(2,2,19) route(2,3,8) route(2,4,15) route(2,5,10) route(3,1,13) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,4) route(4,4,9) route(4,5,16) route(5,1,3) route(5,2,12) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 80
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,22) route(1,5,7) route(2,1,18) route(2,2,23) route(2,3,8) route(2,4,13) route(2,5,16) route(3,1,11) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,21) route(4,1,24) route(4,2,19) route(4,3,4) route(4,4,9) route(4,5,14) route(5,1,3) route(5,2,10) route(5,3,25) route(5,4,20) route(5,5,5)
# Answer: 81
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,22) route(1,5,7) route(2,1,10) route(2,2,23) route(2,3,8) route(2,4,17) route(2,5,12) route(3,1,15) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,21) route(4,1,24) route(4,2,9) route(4,3,4) route(4,4,13) route(4,5,18) route(5,1,3) route(5,2,14) route(5,3,25) route(5,4,20) route(5,5,5)
# Answer: 82
# route(1,1,1) route(1,2,14) route(1,3,7) route(1,4,20) route(1,5,25) route(2,1,8) route(2,2,19) route(2,3,24) route(2,4,15) route(2,5,10) route(3,1,13) route(3,2,2) route(3,3,9) route(3,4,6) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,4) route(4,4,11) route(4,5,16) route(5,1,3) route(5,2,12) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 83
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,20) route(1,5,25) route(2,1,18) route(2,2,7) route(2,3,24) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,21) route(4,1,8) route(4,2,23) route(4,3,4) route(4,4,15) route(4,5,10) route(5,1,3) route(5,2,14) route(5,3,9) route(5,4,22) route(5,5,5)
# Answer: 84
# route(1,1,1) route(1,2,24) route(1,3,11) route(1,4,18) route(1,5,7) route(2,1,10) route(2,2,19) route(2,3,8) route(2,4,23) route(2,5,12) route(3,1,25) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,17) route(4,1,20) route(4,2,9) route(4,3,4) route(4,4,13) route(4,5,22) route(5,1,3) route(5,2,14) route(5,3,21) route(5,4,16) route(5,5,5)
# Answer: 85
# route(1,1,1) route(1,2,12) route(1,3,21) route(1,4,16) route(1,5,25) route(2,1,20) route(2,2,7) route(2,3,24) route(2,4,11) route(2,5,22) route(3,1,13) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,17) route(4,1,8) route(4,2,19) route(4,3,4) route(4,4,23) route(4,5,10) route(5,1,3) route(5,2,14) route(5,3,9) route(5,4,18) route(5,5,5)
# Answer: 86
# route(1,1,1) route(1,2,16) route(1,3,13) route(1,4,22) route(1,5,7) route(2,1,14) route(2,2,21) route(2,3,8) route(2,4,17) route(2,5,12) route(3,1,9) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,23) route(4,1,20) route(4,2,25) route(4,3,4) route(4,4,11) route(4,5,18) route(5,1,3) route(5,2,10) route(5,3,19) route(5,4,24) route(5,5,5)
# Answer: 87
# route(1,1,1) route(1,2,22) route(1,3,13) route(1,4,16) route(1,5,7) route(2,1,12) route(2,2,17) route(2,3,8) route(2,4,21) route(2,5,14) route(3,1,23) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,9) route(4,1,18) route(4,2,11) route(4,3,4) route(4,4,25) route(4,5,20) route(5,1,3) route(5,2,24) route(5,3,19) route(5,4,10) route(5,5,5)
# Answer: 88
# route(1,1,1) route(1,2,20) route(1,3,13) route(1,4,8) route(1,5,25) route(2,1,12) route(2,2,7) route(2,3,24) route(2,4,19) route(2,5,14) route(3,1,21) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,9) route(4,1,16) route(4,2,11) route(4,3,4) route(4,4,23) route(4,5,18) route(5,1,3) route(5,2,22) route(5,3,17) route(5,4,10) route(5,5,5)
# Answer: 89
# route(1,1,1) route(1,2,22) route(1,3,17) route(1,4,12) route(1,5,7) route(2,1,16) route(2,2,13) route(2,3,8) route(2,4,23) route(2,5,18) route(3,1,21) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,19) route(4,5,24) route(5,1,3) route(5,2,20) route(5,3,25) route(5,4,10) route(5,5,5)
# Answer: 90
# route(1,1,1) route(1,2,24) route(1,3,19) route(1,4,10) route(1,5,7) route(2,1,18) route(2,2,11) route(2,3,8) route(2,4,25) route(2,5,20) route(3,1,23) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,17) route(4,3,4) route(4,4,21) route(4,5,14) route(5,1,3) route(5,2,22) route(5,3,13) route(5,4,16) route(5,5,5)
# Answer: 91
# route(1,1,1) route(1,2,10) route(1,3,19) route(1,4,24) route(1,5,7) route(2,1,20) route(2,2,25) route(2,3,8) route(2,4,11) route(2,5,18) route(3,1,9) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,23) route(4,1,14) route(4,2,21) route(4,3,4) route(4,4,17) route(4,5,12) route(5,1,3) route(5,2,16) route(5,3,13) route(5,4,22) route(5,5,5)
# Answer: 92
# route(1,1,1) route(1,2,18) route(1,3,11) route(1,4,24) route(1,5,7) route(2,1,12) route(2,2,23) route(2,3,8) route(2,4,19) route(2,5,10) route(3,1,17) route(3,2,2) route(3,3,15) route(3,4,6) route(3,5,25) route(4,1,22) route(4,2,13) route(4,3,4) route(4,4,9) route(4,5,20) route(5,1,3) route(5,2,16) route(5,3,21) route(5,4,14) route(5,5,5)
# Answer: 93
# route(1,1,1) route(1,2,16) route(1,3,7) route(1,4,22) route(1,5,25) route(2,1,8) route(2,2,21) route(2,3,24) route(2,4,17) route(2,5,12) route(3,1,15) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,23) route(4,1,20) route(4,2,9) route(4,3,4) route(4,4,13) route(4,5,18) route(5,1,3) route(5,2,14) route(5,3,19) route(5,4,10) route(5,5,5)
# Answer: 94
# route(1,1,1) route(1,2,18) route(1,3,23) route(1,4,12) route(1,5,7) route(2,1,24) route(2,2,13) route(2,3,8) route(2,4,17) route(2,5,22) route(3,1,19) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,9) route(4,1,14) route(4,2,25) route(4,3,4) route(4,4,21) route(4,5,16) route(5,1,3) route(5,2,20) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 95
# route(1,1,1) route(1,2,24) route(1,3,13) route(1,4,18) route(1,5,7) route(2,1,14) route(2,2,19) route(2,3,8) route(2,4,23) route(2,5,12) route(3,1,25) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,17) route(4,1,20) route(4,2,15) route(4,3,4) route(4,4,9) route(4,5,22) route(5,1,3) route(5,2,10) route(5,3,21) route(5,4,16) route(5,5,5)
# Answer: 96
# route(1,1,1) route(1,2,10) route(1,3,15) route(1,4,20) route(1,5,7) route(2,1,16) route(2,2,21) route(2,3,8) route(2,4,25) route(2,5,14) route(3,1,9) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,19) route(4,1,22) route(4,2,17) route(4,3,4) route(4,4,13) route(4,5,24) route(5,1,3) route(5,2,12) route(5,3,23) route(5,4,18) route(5,5,5)
# Answer: 97
# route(1,1,1) route(1,2,12) route(1,3,23) route(1,4,18) route(1,5,7) route(2,1,22) route(2,2,17) route(2,3,8) route(2,4,13) route(2,5,24) route(3,1,9) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,19) route(4,1,16) route(4,2,21) route(4,3,4) route(4,4,25) route(4,5,14) route(5,1,3) route(5,2,10) route(5,3,15) route(5,4,20) route(5,5,5)
# Answer: 98
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,8) route(1,5,25) route(2,1,22) route(2,2,7) route(2,3,24) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,23) route(4,3,4) route(4,4,19) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,10) route(5,5,5)
# Answer: 99
# route(1,1,1) route(1,2,22) route(1,3,7) route(1,4,16) route(1,5,25) route(2,1,12) route(2,2,17) route(2,3,24) route(2,4,21) route(2,5,8) route(3,1,23) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,15) route(4,1,18) route(4,2,13) route(4,3,4) route(4,4,9) route(4,5,20) route(5,1,3) route(5,2,10) route(5,3,19) route(5,4,14) route(5,5,5)
# Answer: 100
# route(1,1,1) route(1,2,20) route(1,3,15) route(1,4,10) route(1,5,7) route(2,1,14) route(2,2,25) route(2,3,8) route(2,4,21) route(2,5,16) route(3,1,19) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,9) route(4,1,24) route(4,2,13) route(4,3,4) route(4,4,17) route(4,5,22) route(5,1,3) route(5,2,18) route(5,3,23) route(5,4,12) route(5,5,5)
# Answer: 101
# route(1,1,1) route(1,2,20) route(1,3,25) route(1,4,14) route(1,5,7) route(2,1,10) route(2,2,15) route(2,3,8) route(2,4,19) route(2,5,24) route(3,1,21) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,13) route(4,1,16) route(4,2,9) route(4,3,4) route(4,4,23) route(4,5,18) route(5,1,3) route(5,2,22) route(5,3,17) route(5,4,12) route(5,5,5)
# Answer: 102
# route(1,1,1) route(1,2,20) route(1,3,9) route(1,4,14) route(1,5,25) route(2,1,8) route(2,2,15) route(2,3,24) route(2,4,19) route(2,5,10) route(3,1,21) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,13) route(4,1,16) route(4,2,7) route(4,3,4) route(4,4,23) route(4,5,18) route(5,1,3) route(5,2,22) route(5,3,17) route(5,4,12) route(5,5,5)
# Answer: 103
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,24) route(1,5,7) route(2,1,12) route(2,2,23) route(2,3,8) route(2,4,19) route(2,5,14) route(3,1,17) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,25) route(4,1,22) route(4,2,9) route(4,3,4) route(4,4,15) route(4,5,20) route(5,1,3) route(5,2,16) route(5,3,21) route(5,4,10) route(5,5,5)
# Answer: 104
# route(1,1,1) route(1,2,14) route(1,3,19) route(1,4,10) route(1,5,25) route(2,1,20) route(2,2,9) route(2,3,24) route(2,4,13) route(2,5,18) route(3,1,15) route(3,2,2) route(3,3,11) route(3,4,6) route(3,5,23) route(4,1,8) route(4,2,21) route(4,3,4) route(4,4,17) route(4,5,12) route(5,1,3) route(5,2,16) route(5,3,7) route(5,4,22) route(5,5,5)
# Answer: 105
# route(1,1,1) route(1,2,20) route(1,3,15) route(1,4,12) route(1,5,7) route(2,1,14) route(2,2,25) route(2,3,8) route(2,4,21) route(2,5,16) route(3,1,19) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,11) route(4,1,24) route(4,2,9) route(4,3,4) route(4,4,17) route(4,5,22) route(5,1,3) route(5,2,18) route(5,3,23) route(5,4,10) route(5,5,5)
# Answer: 106
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,10) route(1,5,25) route(2,1,22) route(2,2,9) route(2,3,24) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,11) route(4,1,8) route(4,2,23) route(4,3,4) route(4,4,19) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,7) route(5,4,12) route(5,5,5)
# Answer: 107
# route(1,1,1) route(1,2,20) route(1,3,15) route(1,4,10) route(1,5,25) route(2,1,14) route(2,2,9) route(2,3,24) route(2,4,19) route(2,5,16) route(3,1,21) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,11) route(4,1,8) route(4,2,13) route(4,3,4) route(4,4,23) route(4,5,18) route(5,1,3) route(5,2,22) route(5,3,7) route(5,4,12) route(5,5,5)
# Answer: 108
# route(1,1,1) route(1,2,24) route(1,3,19) route(1,4,12) route(1,5,7) route(2,1,18) route(2,2,13) route(2,3,8) route(2,4,25) route(2,5,20) route(3,1,23) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,21) route(4,5,16) route(5,1,3) route(5,2,22) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 109
# route(1,1,1) route(1,2,22) route(1,3,15) route(1,4,10) route(1,5,25) route(2,1,14) route(2,2,9) route(2,3,24) route(2,4,21) route(2,5,16) route(3,1,23) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,11) route(4,1,8) route(4,2,13) route(4,3,4) route(4,4,17) route(4,5,20) route(5,1,3) route(5,2,18) route(5,3,7) route(5,4,12) route(5,5,5)
# Answer: 110
# route(1,1,1) route(1,2,18) route(1,3,21) route(1,4,12) route(1,5,7) route(2,1,20) route(2,2,13) route(2,3,8) route(2,4,17) route(2,5,22) route(3,1,25) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,23) route(4,5,16) route(5,1,3) route(5,2,24) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 111
# route(1,1,1) route(1,2,18) route(1,3,7) route(1,4,12) route(1,5,25) route(2,1,8) route(2,2,13) route(2,3,24) route(2,4,17) route(2,5,20) route(3,1,23) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,21) route(4,5,16) route(5,1,3) route(5,2,22) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 112
# route(1,1,1) route(1,2,18) route(1,3,7) route(1,4,12) route(1,5,25) route(2,1,8) route(2,2,13) route(2,3,24) route(2,4,17) route(2,5,22) route(3,1,19) route(3,2,2) route(3,3,21) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,23) route(4,5,16) route(5,1,3) route(5,2,20) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 113
# route(1,1,1) route(1,2,18) route(1,3,23) route(1,4,12) route(1,5,7) route(2,1,22) route(2,2,13) route(2,3,8) route(2,4,17) route(2,5,24) route(3,1,19) route(3,2,2) route(3,3,21) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,25) route(4,5,16) route(5,1,3) route(5,2,20) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 114
# route(1,1,1) route(1,2,18) route(1,3,25) route(1,4,12) route(1,5,7) route(2,1,24) route(2,2,13) route(2,3,8) route(2,4,17) route(2,5,22) route(3,1,19) route(3,2,2) route(3,3,23) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,21) route(4,5,16) route(5,1,3) route(5,2,20) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 115
# route(1,1,1) route(1,2,18) route(1,3,23) route(1,4,12) route(1,5,7) route(2,1,24) route(2,2,13) route(2,3,8) route(2,4,17) route(2,5,22) route(3,1,19) route(3,2,2) route(3,3,25) route(3,4,6) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,4) route(4,4,21) route(4,5,16) route(5,1,3) route(5,2,20) route(5,3,15) route(5,4,10) route(5,5,5)
# Answer: 116
# route(1,1,1) route(1,2,22) route(1,3,13) route(1,4,8) route(1,5,25) route(2,1,12) route(2,2,7) route(2,3,24) route(2,4,21) route(2,5,14) route(3,1,23) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,9) route(4,1,18) route(4,2,11) route(4,3,4) route(4,4,15) route(4,5,20) route(5,1,3) route(5,2,16) route(5,3,19) route(5,4,10) route(5,5,5)
# Answer: 117
# route(1,1,1) route(1,2,24) route(1,3,13) route(1,4,18) route(1,5,7) route(2,1,12) route(2,2,19) route(2,3,8) route(2,4,23) route(2,5,14) route(3,1,25) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,9) route(4,1,20) route(4,2,11) route(4,3,4) route(4,4,15) route(4,5,22) route(5,1,3) route(5,2,16) route(5,3,21) route(5,4,10) route(5,5,5)
# Answer: 118
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,10) route(1,5,7) route(2,1,20) route(2,2,11) route(2,3,8) route(2,4,15) route(2,5,22) route(3,1,25) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,19) route(4,3,4) route(4,4,23) route(4,5,14) route(5,1,3) route(5,2,24) route(5,3,13) route(5,4,18) route(5,5,5)
# Answer: 119
# route(1,1,1) route(1,2,10) route(1,3,21) route(1,4,16) route(1,5,7) route(2,1,22) route(2,2,15) route(2,3,8) route(2,4,11) route(2,5,20) route(3,1,9) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,25) route(4,1,14) route(4,2,23) route(4,3,4) route(4,4,19) route(4,5,12) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,24) route(5,5,5)
# Answer: 120
# route(1,1,1) route(1,2,16) route(1,3,19) route(1,4,10) route(1,5,25) route(2,1,18) route(2,2,11) route(2,3,24) route(2,4,15) route(2,5,20) route(3,1,23) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,7) route(4,3,4) route(4,4,21) route(4,5,14) route(5,1,3) route(5,2,22) route(5,3,13) route(5,4,8) route(5,5,5)
# Answer: 121
# route(1,1,1) route(1,2,12) route(1,3,19) route(1,4,24) route(1,5,7) route(2,1,20) route(2,2,25) route(2,3,8) route(2,4,13) route(2,5,18) route(3,1,11) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,23) route(4,1,16) route(4,2,21) route(4,3,4) route(4,4,9) route(4,5,14) route(5,1,3) route(5,2,10) route(5,3,15) route(5,4,22) route(5,5,5)
# Answer: 122
# route(1,1,1) route(1,2,20) route(1,3,11) route(1,4,16) route(1,5,7) route(2,1,12) route(2,2,25) route(2,3,8) route(2,4,21) route(2,5,10) route(3,1,19) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,15) route(4,1,24) route(4,2,13) route(4,3,4) route(4,4,9) route(4,5,22) route(5,1,3) route(5,2,18) route(5,3,23) route(5,4,14) route(5,5,5)
# Answer: 123
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,24) route(1,5,7) route(2,1,14) route(2,2,23) route(2,3,8) route(2,4,19) route(2,5,12) route(3,1,9) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,25) route(4,1,22) route(4,2,15) route(4,3,4) route(4,4,11) route(4,5,20) route(5,1,3) route(5,2,10) route(5,3,21) route(5,4,16) route(5,5,5)
# Answer: 124
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,20) route(1,5,7) route(2,1,10) route(2,2,21) route(2,3,8) route(2,4,25) route(2,5,12) route(3,1,15) route(3,2,2) route(3,3,17) route(3,4,6) route(3,5,19) route(4,1,22) route(4,2,9) route(4,3,4) route(4,4,13) route(4,5,24) route(5,1,3) route(5,2,14) route(5,3,23) route(5,4,18) route(5,5,5)
# Answer: 125
# route(1,1,1) route(1,2,20) route(1,3,25) route(1,4,14) route(1,5,7) route(2,1,12) route(2,2,15) route(2,3,8) route(2,4,19) route(2,5,24) route(3,1,21) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,9) route(4,1,16) route(4,2,11) route(4,3,4) route(4,4,23) route(4,5,18) route(5,1,3) route(5,2,22) route(5,3,17) route(5,4,10) route(5,5,5)
# Answer: 126
# route(1,1,1) route(1,2,22) route(1,3,17) route(1,4,10) route(1,5,7) route(2,1,16) route(2,2,11) route(2,3,8) route(2,4,23) route(2,5,18) route(3,1,21) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,15) route(4,3,4) route(4,4,19) route(4,5,24) route(5,1,3) route(5,2,20) route(5,3,25) route(5,4,14) route(5,5,5)
# Answer: 127
# route(1,1,1) route(1,2,16) route(1,3,23) route(1,4,10) route(1,5,7) route(2,1,22) route(2,2,11) route(2,3,8) route(2,4,15) route(2,5,24) route(3,1,17) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,21) route(4,3,4) route(4,4,25) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,20) route(5,5,5)
# Answer: 128
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,20) route(1,5,7) route(2,1,12) route(2,2,21) route(2,3,8) route(2,4,25) route(2,5,14) route(3,1,17) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,9) route(4,1,22) route(4,2,11) route(4,3,4) route(4,4,15) route(4,5,24) route(5,1,3) route(5,2,16) route(5,3,23) route(5,4,10) route(5,5,5)
# Answer: 129
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,10) route(1,5,7) route(2,1,22) route(2,2,11) route(2,3,8) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,2) route(3,3,23) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,25) route(4,3,4) route(4,4,19) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,24) route(5,5,5)
# Answer: 130
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,10) route(1,5,7) route(2,1,22) route(2,2,11) route(2,3,8) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,2) route(3,3,25) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,23) route(4,3,4) route(4,4,19) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,24) route(5,5,5)
# Answer: 131
# route(1,1,1) route(1,2,16) route(1,3,25) route(1,4,10) route(1,5,7) route(2,1,24) route(2,2,11) route(2,3,8) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,2) route(3,3,21) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,23) route(4,3,4) route(4,4,19) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,22) route(5,5,5)
# Answer: 132
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,22) route(1,5,7) route(2,1,12) route(2,2,23) route(2,3,8) route(2,4,19) route(2,5,14) route(3,1,17) route(3,2,2) route(3,3,21) route(3,4,6) route(3,5,9) route(4,1,24) route(4,2,11) route(4,3,4) route(4,4,15) route(4,5,20) route(5,1,3) route(5,2,16) route(5,3,25) route(5,4,10) route(5,5,5)
# Answer: 133
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,24) route(1,5,7) route(2,1,12) route(2,2,23) route(2,3,8) route(2,4,19) route(2,5,14) route(3,1,17) route(3,2,2) route(3,3,25) route(3,4,6) route(3,5,9) route(4,1,22) route(4,2,11) route(4,3,4) route(4,4,15) route(4,5,20) route(5,1,3) route(5,2,16) route(5,3,21) route(5,4,10) route(5,5,5)
# Answer: 134
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,24) route(1,5,7) route(2,1,12) route(2,2,25) route(2,3,8) route(2,4,19) route(2,5,14) route(3,1,17) route(3,2,2) route(3,3,23) route(3,4,6) route(3,5,9) route(4,1,22) route(4,2,11) route(4,3,4) route(4,4,15) route(4,5,20) route(5,1,3) route(5,2,16) route(5,3,21) route(5,4,10) route(5,5,5)
# Answer: 135
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,10) route(1,5,25) route(2,1,20) route(2,2,11) route(2,3,24) route(2,4,15) route(2,5,22) route(3,1,17) route(3,2,2) route(3,3,19) route(3,4,6) route(3,5,9) route(4,1,12) route(4,2,7) route(4,3,4) route(4,4,23) route(4,5,14) route(5,1,3) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,5)
# Answer: 136
# route(1,1,1) route(1,2,22) route(1,3,11) route(1,4,16) route(1,5,7) route(2,1,10) route(2,2,17) route(2,3,8) route(2,4,21) route(2,5,12) route(3,1,23) route(3,2,2) route(3,3,13) route(3,4,6) route(3,5,15) route(4,1,18) route(4,2,9) route(4,3,4) route(4,4,25) route(4,5,20) route(5,1,3) route(5,2,24) route(5,3,19) route(5,4,14) route(5,5,5)
# Answer: 137
# ...
# Answer: 260
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,22) route(1,5,3) route(2,1,18) route(2,2,25) route(2,3,2) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,21) route(4,1,24) route(4,2,19) route(4,3,6) route(4,4,15) route(4,5,10) route(5,1,7) route(5,2,14) route(5,3,9) route(5,4,20) route(5,5,5)
# Answer: 261
# route(1,1,1) route(1,2,12) route(1,3,17) route(1,4,22) route(1,5,3) route(2,1,18) route(2,2,23) route(2,3,2) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,21) route(4,1,24) route(4,2,19) route(4,3,6) route(4,4,15) route(4,5,10) route(5,1,7) route(5,2,14) route(5,3,9) route(5,4,20) route(5,5,5)
# Answer: 262
# route(1,1,1) route(1,2,18) route(1,3,11) route(1,4,24) route(1,5,3) route(2,1,12) route(2,2,23) route(2,3,2) route(2,4,19) route(2,5,10) route(3,1,17) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,25) route(4,1,22) route(4,2,13) route(4,3,6) route(4,4,9) route(4,5,20) route(5,1,7) route(5,2,16) route(5,3,21) route(5,4,14) route(5,5,5)
# Answer: 263
# route(1,1,1) route(1,2,22) route(1,3,11) route(1,4,16) route(1,5,3) route(2,1,12) route(2,2,17) route(2,3,2) route(2,4,23) route(2,5,10) route(3,1,21) route(3,2,8) route(3,3,19) route(3,4,4) route(3,5,15) route(4,1,18) route(4,2,13) route(4,3,6) route(4,4,9) route(4,5,24) route(5,1,7) route(5,2,20) route(5,3,25) route(5,4,14) route(5,5,5)
# Answer: 264
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,20) route(1,5,3) route(2,1,10) route(2,2,21) route(2,3,2) route(2,4,17) route(2,5,12) route(3,1,15) route(3,2,24) route(3,3,19) route(3,4,4) route(3,5,7) route(4,1,22) route(4,2,9) route(4,3,6) route(4,4,13) route(4,5,18) route(5,1,25) route(5,2,14) route(5,3,23) route(5,4,8) route(5,5,5)
# Answer: 265
# route(1,1,1) route(1,2,20) route(1,3,11) route(1,4,16) route(1,5,3) route(2,1,12) route(2,2,17) route(2,3,2) route(2,4,21) route(2,5,10) route(3,1,7) route(3,2,24) route(3,3,19) route(3,4,4) route(3,5,15) route(4,1,18) route(4,2,13) route(4,3,6) route(4,4,9) route(4,5,22) route(5,1,25) route(5,2,8) route(5,3,23) route(5,4,14) route(5,5,5)
# Answer: 266
# route(1,1,1) route(1,2,20) route(1,3,11) route(1,4,16) route(1,5,3) route(2,1,12) route(2,2,25) route(2,3,2) route(2,4,21) route(2,5,10) route(3,1,19) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,15) route(4,1,24) route(4,2,13) route(4,3,6) route(4,4,9) route(4,5,22) route(5,1,7) route(5,2,18) route(5,3,23) route(5,4,14) route(5,5,5)
# Answer: 267
# route(1,1,1) route(1,2,16) route(1,3,11) route(1,4,18) route(1,5,3) route(2,1,10) route(2,2,19) route(2,3,2) route(2,4,23) route(2,5,12) route(3,1,15) route(3,2,24) route(3,3,17) route(3,4,4) route(3,5,7) route(4,1,20) route(4,2,9) route(4,3,6) route(4,4,13) route(4,5,22) route(5,1,25) route(5,2,14) route(5,3,21) route(5,4,8) route(5,5,5)
# Answer: 268
# route(1,1,1) route(1,2,22) route(1,3,11) route(1,4,16) route(1,5,3) route(2,1,12) route(2,2,17) route(2,3,2) route(2,4,21) route(2,5,10) route(3,1,23) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,15) route(4,1,18) route(4,2,13) route(4,3,6) route(4,4,9) route(4,5,20) route(5,1,7) route(5,2,24) route(5,3,19) route(5,4,14) route(5,5,5)
# Answer: 269
# route(1,1,1) route(1,2,22) route(1,3,11) route(1,4,16) route(1,5,3) route(2,1,12) route(2,2,17) route(2,3,2) route(2,4,21) route(2,5,10) route(3,1,25) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,15) route(4,1,18) route(4,2,13) route(4,3,6) route(4,4,9) route(4,5,20) route(5,1,7) route(5,2,24) route(5,3,19) route(5,4,14) route(5,5,5)
# Answer: 270
# route(1,1,1) route(1,2,14) route(1,3,9) route(1,4,24) route(1,5,3) route(2,1,20) route(2,2,25) route(2,3,2) route(2,4,15) route(2,5,10) route(3,1,13) route(3,2,8) route(3,3,19) route(3,4,4) route(3,5,23) route(4,1,18) route(4,2,21) route(4,3,6) route(4,4,11) route(4,5,16) route(5,1,7) route(5,2,12) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 271
# route(1,1,1) route(1,2,24) route(1,3,9) route(1,4,14) route(1,5,3) route(2,1,10) route(2,2,15) route(2,3,2) route(2,4,25) route(2,5,20) route(3,1,23) route(3,2,8) route(3,3,19) route(3,4,4) route(3,5,13) route(4,1,16) route(4,2,11) route(4,3,6) route(4,4,21) route(4,5,18) route(5,1,7) route(5,2,22) route(5,3,17) route(5,4,12) route(5,5,5)
# Answer: 272
# route(1,1,1) route(1,2,14) route(1,3,23) route(1,4,8) route(1,5,3) route(2,1,22) route(2,2,9) route(2,3,2) route(2,4,13) route(2,5,18) route(3,1,15) route(3,2,24) route(3,3,19) route(3,4,4) route(3,5,7) route(4,1,10) route(4,2,21) route(4,3,6) route(4,4,17) route(4,5,12) route(5,1,25) route(5,2,16) route(5,3,11) route(5,4,20) route(5,5,5)
# Answer: 273
# route(1,1,1) route(1,2,12) route(1,3,21) route(1,4,18) route(1,5,3) route(2,1,22) route(2,2,17) route(2,3,2) route(2,4,13) route(2,5,20) route(3,1,11) route(3,2,8) route(3,3,19) route(3,4,4) route(3,5,25) route(4,1,16) route(4,2,23) route(4,3,6) route(4,4,9) route(4,5,14) route(5,1,7) route(5,2,10) route(5,3,15) route(5,4,24) route(5,5,5)
# Answer: 274
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,8) route(1,5,3) route(2,1,12) route(2,2,7) route(2,3,2) route(2,4,23) route(2,5,14) route(3,1,17) route(3,2,24) route(3,3,19) route(3,4,4) route(3,5,9) route(4,1,20) route(4,2,11) route(4,3,6) route(4,4,15) route(4,5,22) route(5,1,25) route(5,2,16) route(5,3,21) route(5,4,10) route(5,5,5)
# Answer: 275
# route(1,1,1) route(1,2,22) route(1,3,9) route(1,4,14) route(1,5,3) route(2,1,10) route(2,2,15) route(2,3,2) route(2,4,23) route(2,5,18) route(3,1,21) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,13) route(4,1,16) route(4,2,11) route(4,3,6) route(4,4,19) route(4,5,24) route(5,1,7) route(5,2,20) route(5,3,25) route(5,4,12) route(5,5,5)
# Answer: 276
# route(1,1,1) route(1,2,14) route(1,3,9) route(1,4,22) route(1,5,3) route(2,1,18) route(2,2,23) route(2,3,2) route(2,4,15) route(2,5,10) route(3,1,13) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,21) route(4,1,24) route(4,2,19) route(4,3,6) route(4,4,11) route(4,5,16) route(5,1,7) route(5,2,12) route(5,3,25) route(5,4,20) route(5,5,5)
# Answer: 277
# route(1,1,1) route(1,2,18) route(1,3,23) route(1,4,12) route(1,5,3) route(2,1,16) route(2,2,11) route(2,3,2) route(2,4,7) route(2,5,22) route(3,1,19) route(3,2,24) route(3,3,17) route(3,4,4) route(3,5,13) route(4,1,10) route(4,2,15) route(4,3,6) route(4,4,21) route(4,5,8) route(5,1,25) route(5,2,20) route(5,3,9) route(5,4,14) route(5,5,5)
# Answer: 278
# route(1,1,1) route(1,2,20) route(1,3,25) route(1,4,12) route(1,5,3) route(2,1,16) route(2,2,11) route(2,3,2) route(2,4,19) route(2,5,24) route(3,1,21) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,13) route(4,1,10) route(4,2,15) route(4,3,6) route(4,4,23) route(4,5,18) route(5,1,7) route(5,2,22) route(5,3,9) route(5,4,14) route(5,5,5)
# Answer: 279
# route(1,1,1) route(1,2,14) route(1,3,21) route(1,4,8) route(1,5,3) route(2,1,20) route(2,2,9) route(2,3,2) route(2,4,13) route(2,5,22) route(3,1,15) route(3,2,24) route(3,3,17) route(3,4,4) route(3,5,7) route(4,1,10) route(4,2,19) route(4,3,6) route(4,4,23) route(4,5,12) route(5,1,25) route(5,2,16) route(5,3,11) route(5,4,18) route(5,5,5)
# Answer: 280
# route(1,1,1) route(1,2,12) route(1,3,23) route(1,4,18) route(1,5,3) route(2,1,22) route(2,2,7) route(2,3,2) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,24) route(3,3,17) route(3,4,4) route(3,5,19) route(4,1,8) route(4,2,21) route(4,3,6) route(4,4,15) route(4,5,10) route(5,1,25) route(5,2,14) route(5,3,9) route(5,4,20) route(5,5,5)
# Answer: 281
# route(1,1,1) route(1,2,12) route(1,3,25) route(1,4,20) route(1,5,3) route(2,1,24) route(2,2,19) route(2,3,2) route(2,4,11) route(2,5,16) route(3,1,13) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,6) route(4,4,15) route(4,5,10) route(5,1,7) route(5,2,14) route(5,3,9) route(5,4,22) route(5,5,5)
# Answer: 282
# route(1,1,1) route(1,2,12) route(1,3,19) route(1,4,24) route(1,5,3) route(2,1,20) route(2,2,25) route(2,3,2) route(2,4,13) route(2,5,18) route(3,1,11) route(3,2,8) route(3,3,17) route(3,4,4) route(3,5,23) route(4,1,16) route(4,2,21) route(4,3,6) route(4,4,9) route(4,5,14) route(5,1,7) route(5,2,10) route(5,3,15) route(5,4,22) route(5,5,5)
# Answer: 283
# route(1,1,1) route(1,2,14) route(1,3,9) route(1,4,20) route(1,5,3) route(2,1,24) route(2,2,19) route(2,3,2) route(2,4,15) route(2,5,10) route(3,1,13) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,21) route(4,1,18) route(4,2,25) route(4,3,6) route(4,4,11) route(4,5,16) route(5,1,7) route(5,2,12) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 284
# route(1,1,1) route(1,2,14) route(1,3,9) route(1,4,20) route(1,5,3) route(2,1,24) route(2,2,19) route(2,3,2) route(2,4,15) route(2,5,10) route(3,1,13) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,21) route(4,1,18) route(4,2,23) route(4,3,6) route(4,4,11) route(4,5,16) route(5,1,7) route(5,2,12) route(5,3,17) route(5,4,22) route(5,5,5)
# Answer: 285
# route(1,1,1) route(1,2,14) route(1,3,9) route(1,4,20) route(1,5,3) route(2,1,16) route(2,2,21) route(2,3,2) route(2,4,25) route(2,5,10) route(3,1,13) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,19) route(4,1,22) route(4,2,17) route(4,3,6) route(4,4,11) route(4,5,24) route(5,1,7) route(5,2,12) route(5,3,23) route(5,4,18) route(5,5,5)
# Answer: 286
# route(1,1,1) route(1,2,12) route(1,3,21) route(1,4,16) route(1,5,3) route(2,1,20) route(2,2,7) route(2,3,2) route(2,4,11) route(2,5,22) route(3,1,13) route(3,2,24) route(3,3,15) route(3,4,4) route(3,5,17) route(4,1,8) route(4,2,19) route(4,3,6) route(4,4,23) route(4,5,10) route(5,1,25) route(5,2,14) route(5,3,9) route(5,4,18) route(5,5,5)
# Answer: 287
# route(1,1,1) route(1,2,12) route(1,3,23) route(1,4,18) route(1,5,3) route(2,1,22) route(2,2,17) route(2,3,2) route(2,4,11) route(2,5,24) route(3,1,13) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,19) route(4,1,16) route(4,2,21) route(4,3,6) route(4,4,25) route(4,5,10) route(5,1,7) route(5,2,14) route(5,3,9) route(5,4,20) route(5,5,5)
# Answer: 288
# route(1,1,1) route(1,2,20) route(1,3,9) route(1,4,14) route(1,5,3) route(2,1,10) route(2,2,25) route(2,3,2) route(2,4,21) route(2,5,16) route(3,1,19) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,13) route(4,1,24) route(4,2,11) route(4,3,6) route(4,4,17) route(4,5,22) route(5,1,7) route(5,2,18) route(5,3,23) route(5,4,12) route(5,5,5)
# Answer: 289
# route(1,1,1) route(1,2,18) route(1,3,23) route(1,4,12) route(1,5,3) route(2,1,24) route(2,2,11) route(2,3,2) route(2,4,17) route(2,5,22) route(3,1,19) route(3,2,8) route(3,3,15) route(3,4,4) route(3,5,13) route(4,1,10) route(4,2,25) route(4,3,6) route(4,4,21) route(4,5,16) route(5,1,7) route(5,2,20) route(5,3,9) route(5,4,14) route(5,5,5)
# Answer: 290
# route(1,1,1) route(1,2,20) route(1,3,13) route(1,4,8) route(1,5,3) route(2,1,12) route(2,2,7) route(2,3,2) route(2,4,19) route(2,5,14) route(3,1,21) route(3,2,24) route(3,3,15) route(3,4,4) route(3,5,9) route(4,1,16) route(4,2,11) route(4,3,6) route(4,4,23) route(4,5,18) route(5,1,25) route(5,2,22) route(5,3,17) route(5,4,10) route(5,5,5)
# Answer: 291
# route(1,1,1) route(1,2,12) route(1,3,25) route(1,4,18) route(1,5,3) route(2,1,22) route(2,2,17) route(2,3,2) route(2,4,13) route(2,5,24) route(3,1,11) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,19) route(4,1,16) route(4,2,21) route(4,3,6) route(4,4,9) route(4,5,14) route(5,1,7) route(5,2,10) route(5,3,15) route(5,4,20) route(5,5,5)
# Answer: 292
# route(1,1,1) route(1,2,12) route(1,3,23) route(1,4,18) route(1,5,3) route(2,1,22) route(2,2,17) route(2,3,2) route(2,4,13) route(2,5,24) route(3,1,11) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,19) route(4,1,16) route(4,2,21) route(4,3,6) route(4,4,9) route(4,5,14) route(5,1,7) route(5,2,10) route(5,3,15) route(5,4,20) route(5,5,5)
# Answer: 293
# route(1,1,1) route(1,2,20) route(1,3,9) route(1,4,14) route(1,5,3) route(2,1,10) route(2,2,15) route(2,3,2) route(2,4,19) route(2,5,24) route(3,1,21) route(3,2,8) route(3,3,23) route(3,4,4) route(3,5,13) route(4,1,16) route(4,2,11) route(4,3,6) route(4,4,25) route(4,5,18) route(5,1,7) route(5,2,22) route(5,3,17) route(5,4,12) route(5,5,5)
# Answer: 294
# route(1,1,1) route(1,2,20) route(1,3,9) route(1,4,14) route(1,5,3) route(2,1,10) route(2,2,15) route(2,3,2) route(2,4,19) route(2,5,24) route(3,1,21) route(3,2,8) route(3,3,25) route(3,4,4) route(3,5,13) route(4,1,16) route(4,2,11) route(4,3,6) route(4,4,23) route(4,5,18) route(5,1,7) route(5,2,22) route(5,3,17) route(5,4,12) route(5,5,5)
# Answer: 295
# route(1,1,1) route(1,2,18) route(1,3,5) route(1,4,12) route(1,5,3) route(2,1,8) route(2,2,13) route(2,3,2) route(2,4,17) route(2,5,6) route(3,1,19) route(3,2,22) route(3,3,7) route(3,4,4) route(3,5,11) route(4,1,14) route(4,2,9) route(4,3,24) route(4,4,21) route(4,5,16) route(5,1,23) route(5,2,20) route(5,3,15) route(5,4,10) route(5,5,25)
# Answer: 296
# route(1,1,1) route(1,2,20) route(1,3,15) route(1,4,10) route(1,5,3) route(2,1,14) route(2,2,9) route(2,3,2) route(2,4,21) route(2,5,16) route(3,1,19) route(3,2,22) route(3,3,7) route(3,4,4) route(3,5,11) route(4,1,8) route(4,2,13) route(4,3,24) route(4,4,17) route(4,5,6) route(5,1,23) route(5,2,18) route(5,3,5) route(5,4,12) route(5,5,25)
# Answer: 297
# route(1,1,1) route(1,2,12) route(1,3,7) route(1,4,18) route(1,5,3) route(2,1,6) route(2,2,19) route(2,3,2) route(2,4,13) route(2,5,8) route(3,1,11) route(3,2,22) route(3,3,15) route(3,4,4) route(3,5,17) route(4,1,20) route(4,2,5) route(4,3,24) route(4,4,9) route(4,5,14) route(5,1,23) route(5,2,10) route(5,3,21) route(5,4,16) route(5,5,25)
# Answer: 298
# route(1,1,1) route(1,2,16) route(1,3,21) route(1,4,10) route(1,5,3) route(2,1,6) route(2,2,11) route(2,3,2) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,22) route(3,3,7) route(3,4,4) route(3,5,9) route(4,1,12) route(4,2,5) route(4,3,24) route(4,4,19) route(4,5,14) route(5,1,23) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,25)
# Answer: 299
# route(1,1,1) route(1,2,14) route(1,3,21) route(1,4,8) route(1,5,3) route(2,1,20) route(2,2,9) route(2,3,2) route(2,4,13) route(2,5,18) route(3,1,15) route(3,2,22) route(3,3,19) route(3,4,4) route(3,5,7) route(4,1,10) route(4,2,5) route(4,3,24) route(4,4,17) route(4,5,12) route(5,1,23) route(5,2,16) route(5,3,11) route(5,4,6) route(5,5,25)
# Answer: 300
# route(1,1,1) route(1,2,20) route(1,3,5) route(1,4,10) route(1,5,3) route(2,1,6) route(2,2,11) route(2,3,2) route(2,4,21) route(2,5,16) route(3,1,19) route(3,2,22) route(3,3,15) route(3,4,4) route(3,5,9) route(4,1,12) route(4,2,7) route(4,3,24) route(4,4,17) route(4,5,14) route(5,1,23) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,25)
# Answer: 301
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,8) route(1,5,3) route(2,1,12) route(2,2,7) route(2,3,2) route(2,4,21) route(2,5,14) route(3,1,17) route(3,2,22) route(3,3,19) route(3,4,4) route(3,5,9) route(4,1,6) route(4,2,11) route(4,3,24) route(4,4,15) route(4,5,20) route(5,1,23) route(5,2,16) route(5,3,5) route(5,4,10) route(5,5,25)
# Answer: 302
# route(1,1,1) route(1,2,18) route(1,3,13) route(1,4,8) route(1,5,3) route(2,1,12) route(2,2,7) route(2,3,2) route(2,4,17) route(2,5,14) route(3,1,19) route(3,2,22) route(3,3,15) route(3,4,4) route(3,5,9) route(4,1,6) route(4,2,11) route(4,3,24) route(4,4,21) route(4,5,16) route(5,1,23) route(5,2,20) route(5,3,5) route(5,4,10) route(5,5,25)
# Answer: 303
# route(1,1,1) route(1,2,16) route(1,3,5) route(1,4,10) route(1,5,3) route(2,1,6) route(2,2,11) route(2,3,2) route(2,4,15) route(2,5,20) route(3,1,17) route(3,2,22) route(3,3,19) route(3,4,4) route(3,5,9) route(4,1,12) route(4,2,7) route(4,3,24) route(4,4,21) route(4,5,14) route(5,1,23) route(5,2,18) route(5,3,13) route(5,4,8) route(5,5,25)
# Answer: 304
# route(1,1,1) route(1,2,14) route(1,3,19) route(1,4,8) route(1,5,3) route(2,1,18) route(2,2,9) route(2,3,2) route(2,4,13) route(2,5,20) route(3,1,15) route(3,2,22) route(3,3,17) route(3,4,4) route(3,5,7) route(4,1,10) route(4,2,5) route(4,3,24) route(4,4,21) route(4,5,12) route(5,1,23) route(5,2,16) route(5,3,11) route(5,4,6) route(5,5,25)
# SATISFIABLE
# Models      : 304
# Calls       : 1
# Time        : 3.009s (Solving: 3.01s 1st Model: 0.00s Unsat: n/a)

# %%
program = r"""

% Board
square(1..3, 1..3).

% Knight moves
move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 1 = |X1-X2|, 2 = |Y1-Y2|.
move(X1,Y1,X2,Y2) :- square(X1,Y1), square(X2,Y2), 2 = |X1-X2|, 1 = |Y1-Y2|.

% Steps
step(1..8).

% Start
route(1,1,1).

% Exactly one square at each step
1 { route(X,Y,Z) : square(X,Y) } 1 :- step(Z).

% Legal moves between consecutive steps
:- step(Z), Z < 8,
   route(X1,Y1,Z), route(X2,Y2,Z+1),
   not move(X1,Y1,X2,Y2).

#show route/3.

"""
solve_asp(program=program, models=0)
# Out:
# Answer: 1
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,3,4) route(3,2,2) route(3,2,6) route(3,2,8)
# Answer: 2
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,1,8) route(2,3,4) route(3,2,2) route(3,2,6)
# Answer: 3
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,4) route(3,2,2) route(3,2,6) route(3,2,8)
# Answer: 4
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,4) route(2,3,8) route(3,2,2) route(3,2,6)
# Answer: 5
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,2,8) route(2,3,4) route(2,3,6) route(3,1,7) route(3,2,2)
# Answer: 6
# route(1,1,1) route(1,1,3) route(1,1,5) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,7) route(3,2,2)
# Answer: 7
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,4) route(2,3,6) route(2,3,8) route(3,2,2)
# Answer: 8
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,4) route(2,3,6) route(3,2,2) route(3,2,8)
# Answer: 9
# route(1,1,1) route(1,1,3) route(1,2,8) route(2,3,4) route(2,3,6) route(3,1,5) route(3,1,7) route(3,2,2)
# Answer: 10
# route(1,1,1) route(1,1,3) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,5) route(3,1,7) route(3,2,2)
# Answer: 11
# route(1,1,1) route(1,1,3) route(1,2,6) route(2,3,4) route(2,3,8) route(3,1,5) route(3,1,7) route(3,2,2)
# Answer: 12
# route(1,1,1) route(1,1,3) route(1,2,6) route(1,2,8) route(2,3,4) route(3,1,5) route(3,1,7) route(3,2,2)
# Answer: 13
# route(1,1,1) route(1,1,3) route(1,2,6) route(2,1,8) route(2,3,4) route(3,1,5) route(3,2,2) route(3,3,7)
# Answer: 14
# route(1,1,1) route(1,1,3) route(1,2,6) route(1,2,8) route(2,3,4) route(3,1,5) route(3,2,2) route(3,3,7)
# Answer: 15
# route(1,1,1) route(1,1,3) route(1,1,7) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,5) route(3,2,2)
# Answer: 16
# route(1,1,1) route(1,1,3) route(1,1,7) route(2,3,4) route(2,3,6) route(3,1,5) route(3,2,2) route(3,2,8)
# Answer: 17
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,1,6) route(3,2,2) route(3,2,4) route(3,2,8)
# Answer: 18
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,1,6) route(2,1,8) route(3,2,2) route(3,2,4)
# Answer: 19
# route(1,1,1) route(1,1,3) route(1,3,5) route(2,1,6) route(2,1,8) route(3,2,2) route(3,2,4) route(3,3,7)
# Answer: 20
# route(1,1,1) route(1,1,3) route(1,2,8) route(1,3,5) route(2,1,6) route(3,2,2) route(3,2,4) route(3,3,7)
# Answer: 21
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 22
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,1,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 23
# route(1,1,1) route(1,1,3) route(1,1,7) route(1,3,5) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 24
# route(1,1,1) route(1,1,3) route(1,1,7) route(1,3,5) route(2,3,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 25
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,1,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 26
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 27
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,2,8) route(2,3,6) route(3,1,7) route(3,2,2) route(3,2,4)
# Answer: 28
# route(1,1,1) route(1,1,3) route(1,1,5) route(2,3,6) route(2,3,8) route(3,1,7) route(3,2,2) route(3,2,4)
# Answer: 29
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 30
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 31
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,6) route(2,3,8) route(3,2,2) route(3,2,4)
# Answer: 32
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,6) route(3,2,2) route(3,2,4) route(3,2,8)
# Answer: 33
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 34
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 35
# route(1,1,1) route(1,1,7) route(1,3,3) route(1,3,5) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 36
# route(1,1,1) route(1,1,7) route(1,3,3) route(1,3,5) route(2,3,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 37
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,6) route(3,2,2) route(3,2,4) route(3,2,8)
# Answer: 38
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,6) route(2,1,8) route(3,2,2) route(3,2,4)
# Answer: 39
# route(1,1,1) route(1,3,3) route(1,3,5) route(2,1,6) route(2,1,8) route(3,2,2) route(3,2,4) route(3,3,7)
# Answer: 40
# route(1,1,1) route(1,2,8) route(1,3,3) route(1,3,5) route(2,1,6) route(3,2,2) route(3,2,4) route(3,3,7)
# Answer: 41
# route(1,1,1) route(1,1,5) route(1,3,3) route(2,3,6) route(2,3,8) route(3,1,7) route(3,2,2) route(3,2,4)
# Answer: 42
# route(1,1,1) route(1,1,5) route(1,2,8) route(1,3,3) route(2,3,6) route(3,1,7) route(3,2,2) route(3,2,4)
# Answer: 43
# route(1,1,1) route(1,1,5) route(1,3,3) route(1,3,7) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 44
# route(1,1,1) route(1,1,5) route(1,3,3) route(1,3,7) route(2,1,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 45
# route(1,1,1) route(1,1,5) route(1,1,7) route(1,3,3) route(2,3,6) route(3,2,2) route(3,2,4) route(3,2,8)
# Answer: 46
# route(1,1,1) route(1,1,5) route(1,1,7) route(1,3,3) route(2,3,6) route(2,3,8) route(3,2,2) route(3,2,4)
# Answer: 47
# route(1,1,1) route(1,1,5) route(1,1,7) route(1,3,3) route(2,3,8) route(3,2,2) route(3,2,4) route(3,2,6)
# Answer: 48
# route(1,1,1) route(1,1,5) route(1,1,7) route(1,3,3) route(3,2,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 49
# route(1,1,1) route(1,2,6) route(1,2,8) route(1,3,3) route(2,1,4) route(3,2,2) route(3,3,5) route(3,3,7)
# Answer: 50
# route(1,1,1) route(1,2,6) route(1,3,3) route(2,1,4) route(2,1,8) route(3,2,2) route(3,3,5) route(3,3,7)
# Answer: 51
# route(1,1,1) route(1,2,6) route(1,3,3) route(2,1,4) route(2,3,8) route(3,1,7) route(3,2,2) route(3,3,5)
# Answer: 52
# route(1,1,1) route(1,2,6) route(1,2,8) route(1,3,3) route(2,1,4) route(3,1,7) route(3,2,2) route(3,3,5)
# Answer: 53
# route(1,1,1) route(1,3,3) route(1,3,7) route(2,1,4) route(2,1,6) route(3,2,2) route(3,2,8) route(3,3,5)
# Answer: 54
# route(1,1,1) route(1,3,3) route(1,3,7) route(2,1,4) route(2,1,6) route(2,1,8) route(3,2,2) route(3,3,5)
# Answer: 55
# route(1,1,1) route(1,2,8) route(1,3,3) route(2,1,4) route(2,1,6) route(3,2,2) route(3,3,5) route(3,3,7)
# Answer: 56
# route(1,1,1) route(1,3,3) route(2,1,4) route(2,1,6) route(2,1,8) route(3,2,2) route(3,3,5) route(3,3,7)
# Answer: 57
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,4) route(2,1,6) route(3,2,2) route(3,2,8)
# Answer: 58
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,4) route(2,1,6) route(2,1,8) route(3,2,2)
# Answer: 59
# route(1,1,1) route(1,3,3) route(1,3,5) route(2,1,4) route(2,1,6) route(2,1,8) route(3,2,2) route(3,3,7)
# Answer: 60
# route(1,1,1) route(1,2,8) route(1,3,3) route(1,3,5) route(2,1,4) route(2,1,6) route(3,2,2) route(3,3,7)
# Answer: 61
# route(1,1,1) route(1,1,7) route(1,3,3) route(1,3,5) route(2,1,4) route(3,2,2) route(3,2,6) route(3,2,8)
# Answer: 62
# route(1,1,1) route(1,1,7) route(1,3,3) route(1,3,5) route(2,1,4) route(2,3,8) route(3,2,2) route(3,2,6)
# Answer: 63
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,4) route(3,2,2) route(3,2,6) route(3,2,8)
# Answer: 64
# route(1,1,1) route(1,3,3) route(1,3,5) route(1,3,7) route(2,1,4) route(2,1,8) route(3,2,2) route(3,2,6)
# Answer: 65
# route(1,1,1) route(1,2,4) route(1,2,6) route(2,1,8) route(2,3,2) route(3,1,3) route(3,3,5) route(3,3,7)
# Answer: 66
# route(1,1,1) route(1,2,4) route(1,2,6) route(1,2,8) route(2,3,2) route(3,1,3) route(3,3,5) route(3,3,7)
# Answer: 67
# route(1,1,1) route(1,2,4) route(1,2,6) route(1,2,8) route(2,3,2) route(3,1,3) route(3,1,7) route(3,3,5)
# Answer: 68
# route(1,1,1) route(1,2,4) route(1,2,6) route(2,3,2) route(2,3,8) route(3,1,3) route(3,1,7) route(3,3,5)
# Answer: 69
# route(1,1,1) route(1,2,4) route(1,3,7) route(2,1,6) route(2,3,2) route(3,1,3) route(3,2,8) route(3,3,5)
# Answer: 70
# route(1,1,1) route(1,2,4) route(1,3,7) route(2,1,6) route(2,1,8) route(2,3,2) route(3,1,3) route(3,3,5)
# Answer: 71
# route(1,1,1) route(1,2,4) route(2,1,6) route(2,1,8) route(2,3,2) route(3,1,3) route(3,3,5) route(3,3,7)
# Answer: 72
# route(1,1,1) route(1,2,4) route(1,2,8) route(2,1,6) route(2,3,2) route(3,1,3) route(3,3,5) route(3,3,7)
# Answer: 73
# route(1,1,1) route(1,2,4) route(1,2,6) route(2,1,8) route(2,3,2) route(3,1,3) route(3,1,5) route(3,3,7)
# Answer: 74
# route(1,1,1) route(1,2,4) route(1,2,6) route(1,2,8) route(2,3,2) route(3,1,3) route(3,1,5) route(3,3,7)
# Answer: 75
# route(1,1,1) route(1,2,4) route(1,2,6) route(1,2,8) route(2,3,2) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 76
# route(1,1,1) route(1,2,4) route(1,2,6) route(2,3,2) route(2,3,8) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 77
# route(1,1,1) route(1,2,6) route(1,2,8) route(2,3,2) route(2,3,4) route(3,1,3) route(3,1,5) route(3,3,7)
# Answer: 78
# route(1,1,1) route(1,2,6) route(2,1,8) route(2,3,2) route(2,3,4) route(3,1,3) route(3,1,5) route(3,3,7)
# Answer: 79
# route(1,1,1) route(1,2,6) route(2,3,2) route(2,3,4) route(2,3,8) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 80
# route(1,1,1) route(1,2,6) route(1,2,8) route(2,3,2) route(2,3,4) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 81
# route(1,1,1) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,8) route(3,1,3) route(3,2,6)
# Answer: 82
# route(1,1,1) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(3,1,3) route(3,2,6) route(3,2,8)
# Answer: 83
# route(1,1,1) route(1,1,5) route(1,3,7) route(2,3,2) route(2,3,4) route(3,1,3) route(3,2,6) route(3,2,8)
# Answer: 84
# route(1,1,1) route(1,1,5) route(1,3,7) route(2,1,8) route(2,3,2) route(2,3,4) route(3,1,3) route(3,2,6)
# Answer: 85
# route(1,1,1) route(1,1,3) route(1,2,6) route(1,2,8) route(2,3,2) route(2,3,4) route(3,1,5) route(3,3,7)
# Answer: 86
# route(1,1,1) route(1,1,3) route(1,2,6) route(2,1,8) route(2,3,2) route(2,3,4) route(3,1,5) route(3,3,7)
# Answer: 87
# route(1,1,1) route(1,1,3) route(1,2,6) route(1,2,8) route(2,3,2) route(2,3,4) route(3,1,5) route(3,1,7)
# Answer: 88
# route(1,1,1) route(1,1,3) route(1,2,6) route(2,3,2) route(2,3,4) route(2,3,8) route(3,1,5) route(3,1,7)
# Answer: 89
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,1,8) route(2,3,2) route(2,3,4) route(3,2,6)
# Answer: 90
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,3,2) route(2,3,4) route(3,2,6) route(3,2,8)
# Answer: 91
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,8) route(3,2,6)
# Answer: 92
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(3,2,6) route(3,2,8)
# Answer: 93
# route(1,1,1) route(1,1,3) route(1,3,5) route(2,1,6) route(2,1,8) route(2,3,2) route(3,2,4) route(3,3,7)
# Answer: 94
# route(1,1,1) route(1,1,3) route(1,2,8) route(1,3,5) route(2,1,6) route(2,3,2) route(3,2,4) route(3,3,7)
# Answer: 95
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,1,6) route(2,3,2) route(3,2,4) route(3,2,8)
# Answer: 96
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,1,6) route(2,1,8) route(2,3,2) route(3,2,4)
# Answer: 97
# route(1,1,1) route(1,1,3) route(1,1,7) route(1,3,5) route(2,3,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 98
# route(1,1,1) route(1,1,3) route(1,1,7) route(1,3,5) route(2,3,2) route(2,3,8) route(3,2,4) route(3,2,6)
# Answer: 99
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,3,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 100
# route(1,1,1) route(1,1,3) route(1,3,5) route(1,3,7) route(2,1,8) route(2,3,2) route(3,2,4) route(3,2,6)
# Answer: 101
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 102
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,8) route(3,2,4) route(3,2,6)
# Answer: 103
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,3,2) route(3,2,4) route(3,2,6) route(3,2,8)
# Answer: 104
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,3,7) route(2,1,8) route(2,3,2) route(3,2,4) route(3,2,6)
# Answer: 105
# route(1,1,1) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,3) route(3,1,5)
# Answer: 106
# route(1,1,1) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,3) route(3,1,5) route(3,2,8)
# Answer: 107
# route(1,1,1) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 108
# route(1,1,1) route(1,2,8) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 109
# route(1,1,1) route(1,1,7) route(1,2,4) route(2,3,2) route(2,3,6) route(2,3,8) route(3,1,3) route(3,1,5)
# Answer: 110
# route(1,1,1) route(1,1,7) route(1,2,4) route(2,3,2) route(2,3,6) route(3,1,3) route(3,1,5) route(3,2,8)
# Answer: 111
# route(1,1,1) route(1,2,4) route(1,2,8) route(2,3,2) route(2,3,6) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 112
# route(1,1,1) route(1,2,4) route(2,3,2) route(2,3,6) route(2,3,8) route(3,1,3) route(3,1,5) route(3,1,7)
# Answer: 113
# route(1,1,1) route(1,1,3) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,5) route(3,2,8)
# Answer: 114
# route(1,1,1) route(1,1,3) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,5)
# Answer: 115
# route(1,1,1) route(1,1,3) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,5) route(3,1,7)
# Answer: 116
# route(1,1,1) route(1,1,3) route(1,2,8) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,5) route(3,1,7)
# Answer: 117
# route(1,1,1) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,3) route(3,2,8)
# Answer: 118
# route(1,1,1) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,3)
# Answer: 119
# route(1,1,1) route(1,1,5) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,3) route(3,1,7)
# Answer: 120
# route(1,1,1) route(1,1,5) route(1,2,8) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,3) route(3,1,7)
# Answer: 121
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8)
# Answer: 122
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,4) route(2,3,6) route(3,2,8)
# Answer: 123
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,2,8) route(2,3,2) route(2,3,4) route(2,3,6) route(3,1,7)
# Answer: 124
# route(1,1,1) route(1,1,3) route(1,1,5) route(2,3,2) route(2,3,4) route(2,3,6) route(2,3,8) route(3,1,7)
# Answer: 125
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,6) route(2,3,8) route(3,2,4)
# Answer: 126
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,1,7) route(2,3,2) route(2,3,6) route(3,2,4) route(3,2,8)
# Answer: 127
# route(1,1,1) route(1,1,3) route(1,1,5) route(2,3,2) route(2,3,6) route(2,3,8) route(3,1,7) route(3,2,4)
# Answer: 128
# route(1,1,1) route(1,1,3) route(1,1,5) route(1,2,8) route(2,3,2) route(2,3,6) route(3,1,7) route(3,2,4)
# SATISFIABLE
# Models      : 128
# Calls       : 1
# Time        : 0.009s (Solving: 0.01s 1st Model: 0.00s Unsat: n/a)
